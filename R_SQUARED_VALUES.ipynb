# %% [markdown]
# Curve fitting - Non-Linear Least square fitting

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Curve Fitting - Nonlinear least square fitting
calculated_mu = [
    0.7681, 0.5105, 0.4387, 0.4044, 0.3829,
    1.0863, 0.7220, 0.6204, 0.5719, 0.5416,
    1.2080, 0.8029, 0.6899, 0.6360, 0.6023,
    1.1285, 0.7501, 0.6445, 0.5941, 0.5626
]

# Provided actual mu_data values
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu)), max(max(actual_mu), max(calculated_mu)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared = r2_score(actual_mu, calculated_mu)

plt.title('Scatterplot: Actual vs Calculated mu')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# BASIN HOPPING

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Basin Hopping method
calculated_mu_basin_hopping = [
    0.7563, 0.5748, 0.4839, 0.4268, 0.3844,
    0.9487, 0.7210, 0.6071, 0.5354, 0.4822,
    1.0602, 0.8058, 0.6784, 0.5983, 0.5388,
    1.0957, 0.8328, 0.7012, 0.6184, 0.5569
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_basin_hopping, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_basin_hopping)), max(max(actual_mu), max(calculated_mu_basin_hopping)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_basin_hopping = r2_score(actual_mu, calculated_mu_basin_hopping)

plt.title('Scatterplot: Actual vs Calculated mu (Basin Hopping)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_basin_hopping:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# DIFFERENTIAL EVOLUTION

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Differential Evolution method
calculated_mu_differential_evolution = [
    0.7951, 0.5747, 0.4764, 0.4178, 0.3759,
    0.9949, 0.7191, 0.5960, 0.5228, 0.4703,
    1.1255, 0.8135, 0.6743, 0.5914, 0.5320,
    1.1781, 0.8516, 0.7058, 0.6191, 0.5569
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_differential_evolution, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_differential_evolution)), max(max(actual_mu), max(calculated_mu_differential_evolution)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_differential_evolution = r2_score(actual_mu, calculated_mu_differential_evolution)

plt.title('Scatterplot: Actual vs Calculated mu (Differential Evolution)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_differential_evolution:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# CONJUGATE GRADIENT

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Conjugate Gradient method
calculated_mu_conjugate_gradient = [
    0.7308, 0.5741, 0.4760, 0.4073, 0.3526,
    1.0945, 0.8598, 0.7129, 0.6100, 0.5280,
    1.0348, 0.8129, 0.6740, 0.5767, 0.4992,
    1.0290, 0.8084, 0.6703, 0.5735, 0.4965
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_conjugate_gradient, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_conjugate_gradient)), max(max(actual_mu), max(calculated_mu_conjugate_gradient)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_conjugate_gradient = r2_score(actual_mu, calculated_mu_conjugate_gradient)

plt.title('Scatterplot: Actual vs Calculated mu (Conjugate Gradient)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_conjugate_gradient:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# POWELL TECHNIQUE

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Powell method
calculated_mu_powell = [
    0.7594, 0.5731, 0.4793, 0.4202, 0.3762,
    0.9528, 0.7191, 0.6014, 0.5272, 0.4720,
    1.0750, 0.8113, 0.6785, 0.5948, 0.5325,
    1.1242, 0.8485, 0.7096, 0.6220, 0.5569
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_powell, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_powell)), max(max(actual_mu), max(calculated_mu_powell)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_powell = r2_score(actual_mu, calculated_mu_powell)

plt.title('Scatterplot: Actual vs Calculated mu (Powell)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_powell:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# NELDER-MEAD

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using Nelder-Mead method
calculated_mu_nelder_mead = [
    0.7296, 0.5739, 0.4823, 0.4200, 0.3713,
    0.9664, 0.7601, 0.6388, 0.5563, 0.4918,
    1.0626, 0.8358, 0.7024, 0.6117, 0.5408,
    1.0608, 0.8344, 0.7012, 0.6106, 0.5399
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_nelder_mead, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_nelder_mead)), max(max(actual_mu), max(calculated_mu_nelder_mead)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_nelder_mead = r2_score(actual_mu, calculated_mu_nelder_mead)

plt.title('Scatterplot: Actual vs Calculated mu (Nelder-Mead)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_nelder_mead:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# LUPKER

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using LUPKER method
calculated_mu_lupker = [
    0.8571, 0.5748, 0.4839, 0.4376, 0.4074,
    1.0348, 0.6940, 0.5843, 0.5284, 0.4919,
    1.1714, 0.7856, 0.6614, 0.5981, 0.5569,
    1.1714, 0.7856, 0.6615, 0.5981, 0.5569
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot for LUPKER
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_lupker, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_lupker)), max(max(actual_mu), max(calculated_mu_lupker)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_lupker = r2_score(actual_mu, calculated_mu_lupker)

plt.title('Scatterplot: Actual vs Calculated mu (LUPKER)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_lupker:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# WRIGGERS

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using WRIGGERS method
calculated_mu_wriggers = [
    0.8929, 0.6005, 0.4931, 0.4348, 0.3954,
    0.9639, 0.6715, 0.5640, 0.5058, 0.4663,
    1.0348, 0.7424, 0.6350, 0.5767, 0.5373,
    1.1057, 0.8134, 0.7059, 0.6477, 0.6082
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot for WRIGGERS
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_wriggers, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_wriggers)), max(max(actual_mu), max(calculated_mu_wriggers)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_wriggers = r2_score(actual_mu, calculated_mu_wriggers)

plt.title('Scatterplot: Actual vs Calculated mu (WRIGGERS)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_wriggers:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# DORSH

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using DORSH method
calculated_mu_dorsh = [
    0.9104, 0.5933, 0.4934, 0.4429, 0.4103,
    1.0317, 0.6723, 0.5591, 0.5019, 0.4650,
    1.1691, 0.7619, 0.6336, 0.5688, 0.5269,
    1.3248, 0.8634, 0.7180, 0.6446, 0.5971
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot for DORSH
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_dorsh, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_dorsh)), max(max(actual_mu), max(calculated_mu_dorsh)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_dorsh = r2_score(actual_mu, calculated_mu_dorsh)

plt.title('Scatterplot: Actual vs Calculated mu (Dorsh)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_dorsh:.4f}', fontsize=12, color='red')

# Show plot
plt.show()

# %% [markdown]
# WRIGGERS AND REINELT

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Provided calculated mu values using WRIGGERS AND REINELTS method
calculated_mu_wriggers_reinelts = [
    0.7415, 0.6115, 0.4931, 0.4009, 0.3336,
    0.8823, 0.7269, 0.5843, 0.4728, 0.3909,
    1.0499, 0.8650, 0.6952, 0.5625, 0.4650,
    1.2492, 1.0293, 0.8273, 0.6693, 0.5534
]

# Provided actual mu_data values (same as before)
mu_data = [
    [0.7296, 0.5748, 0.4931, 0.3307, 0.4274],
    [1.0348, 0.7191, 0.5843, 0.5019, 0.4944],
    [1.0348, 0.9028, 0.7256, 0.5767, 0.5393],
    [1.3250, 0.8516, 0.7012, 0.5661, 0.5569]
]

# Flatten the actual mu_data values
actual_mu = np.array(mu_data).flatten()

# Plot scatter plot for WRIGGERS AND REINELTS
plt.figure(figsize=(8, 6))
plt.scatter(actual_mu, calculated_mu_wriggers_reinelts, color='blue', label='Calculated vs. Actual Mu')

# Fit a line (y = x) to show ideal relationship
x_line = np.linspace(min(min(actual_mu), min(calculated_mu_wriggers_reinelts)), max(max(actual_mu), max(calculated_mu_wriggers_reinelts)), 100)
plt.plot(x_line, x_line, color='red', linestyle='--', label='Ideal Relationship (y = x)')

# Calculate R-squared value
r_squared_wriggers_reinelts = r2_score(actual_mu, calculated_mu_wriggers_reinelts)

plt.title('Scatterplot: Actual vs Calculated mu (WRIGGERS AND REINELTS)')
plt.xlabel('Actual mu values')
plt.ylabel('Calculated mu values')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Display R-squared value
plt.figtext(0.15, 0.02, f'R-squared value: {r_squared_wriggers_reinelts:.4f}', fontsize=12, color='red')

# Show plot
plt.show()
